# %%
class Student():
    def __init__(self,name = None,gender = "Male") -> None:
        self.name = name
        self.gender = gender
    
    
a = Student("Lyy")
print(a.__dict__)
print(a.__class__)
print(a.__delattr__)
print(a.__doc__)
print(a.__module__)
# Out:
# {'name': 'Lyy', 'gender': 'Male'}
# <class '__main__.Student'>
# <method-wrapper '__delattr__' of Student object at 0x1109e03e0>
# None
# __main__
